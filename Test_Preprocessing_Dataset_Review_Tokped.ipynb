# %%
import numpy as np
import pandas as pd
from nltk.tokenize import word_tokenize
import nltk
nltk.download('punkt')
import re #regex library
import unicodedata
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
df = pd.read_csv('/content/dataset_review_tokped.csv',index_col=[0])

# %%
df['Review'] = df['Review'].astype('str')

# %%
df["Review"].iloc[574]
# Out:
# 'enak sekali..pada saat pengiriman hampir saja tdk diterima. Namun tdk begitu lama pengirim datang.'

# %%
#remove messy enter charracter
df.replace(to_replace=[r"\\t|\\n|\\r", "\t|\n|\r"], value=[" "," "], regex=True, inplace=True)

# %%
#remove emoji
df['Review'] = df['Review'].str.replace('[^\w\s#@/:%.,_-]', '', flags=re.UNICODE)
df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#                                                  Review  Rating
# 0                                              maaantap       5
# 1                                           Enak  segar       5
# 2                                               maknyus       5
# 3     Dari berat 500 gram yg remuk 59 gram. Entah da...       4
# 4                         enak banget, fresh dan renyah       5
# ...                                                 ...     ...
# 5423                      good product, trusted seller        5
# 5424                              sudah beli yg ke 3 ..       5
# 5425                                    byk campurannya       4
# 5426                                               good       5
# 5427                                               good       4
#
# [5428 rows x 2 columns]

# %%
#conver data to lowercase
df['Review'] = df['Review'].str.lower()
df
# Out:
#                                                  Review  Rating
# 0                                              maaantap       5
# 1                                           enak  segar       5
# 2                                               maknyus       5
# 3     dari berat 500 gram yg remuk 59 gram. entah da...       4
# 4                         enak banget, fresh dan renyah       5
# ...                                                 ...     ...
# 5423                      good product, trusted seller        5
# 5424                              sudah beli yg ke 3 ..       5
# 5425                                    byk campurannya       4
# 5426                                               good       5
# 5427                                               good       4
#
# [5428 rows x 2 columns]

# %%
# remove punctuation
df["Review"] = df['Review'].str.replace('[^\w\s]',' ')
df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#                                                  Review  Rating
# 0                                              maaantap       5
# 1                                           enak  segar       5
# 2                                               maknyus       5
# 3     dari berat 500 gram yg remuk 59 gram  entah da...       4
# 4                         enak banget  fresh dan renyah       5
# ...                                                 ...     ...
# 5423                      good product  trusted seller        5
# 5424                              sudah beli yg ke 3          5
# 5425                                    byk campurannya       4
# 5426                                               good       5
# 5427                                               good       4
#
# [5428 rows x 2 columns]

# %%
# multiple space
df['Review'] = df['Review'].str.replace(' {2,}', ' ', regex=True)
df['Review'] = df['Review'].str.strip()
df
# Out:
#                                                  Review  Rating
# 0                                              maaantap       5
# 1                                            enak segar       5
# 2                                               maknyus       5
# 3     dari berat 500 gram yg remuk 59 gram entah dar...       4
# 4                          enak banget fresh dan renyah       5
# ...                                                 ...     ...
# 5423                        good product trusted seller       5
# 5424                                 sudah beli yg ke 3       5
# 5425                                    byk campurannya       4
# 5426                                               good       5
# 5427                                               good       4
#
# [5428 rows x 2 columns]

# %%
#Drop Empty Rows
print(df.isnull().sum())
df.dropna(inplace = True)
print(df.isnull().sum())
df['Review'].astype(bool)
df = df[df['Review'].astype(bool)]
df
# Out:
# Review    0
# Rating    0
# dtype: int64
# Review    0
# Rating    0
# dtype: int64
#                                                  Review  Rating
# 0                                              maaantap       5
# 1                                            enak segar       5
# 2                                               maknyus       5
# 3     dari berat 500 gram yg remuk 59 gram entah dar...       4
# 4                          enak banget fresh dan renyah       5
# ...                                                 ...     ...
# 5423                        good product trusted seller       5
# 5424                                 sudah beli yg ke 3       5
# 5425                                    byk campurannya       4
# 5426                                               good       5
# 5427                                               good       4
#
# [5333 rows x 2 columns]

# %%
#Removes duplicates in place
df.drop_duplicates(keep=False, inplace=True)
df
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#                                                  Review  Rating
# 10                                        enak kuacinya       5
# 12    pengiriman cepat packing bagus sesuai pesanan ...       5
# 13    pengemasan luar biasa baik untuk rasa menurut ...       4
# 15                                      terimakasih min       5
# 16                   udah order untuk kesekian kali jos       5
# ...                                                 ...     ...
# 5421  seller sangat responsif rasa belum dicoba kare...       5
# 5422                          imut2 banget packing aman       5
# 5423                        good product trusted seller       5
# 5424                                 sudah beli yg ke 3       5
# 5425                                    byk campurannya       4
#
# [4060 rows x 2 columns]

# %%
def remove_accented_chars(text):
    text = unicodedata.normalize('NFKD', text).encode('ascii', 'ignore').decode('utf-8', 'ignore')
    return text
    
df['Review'] = df['Review'].apply(remove_accented_chars)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
#remove number
def remove_number(text):
    return  re.sub(r"\d+", "", text)

df['Review'] = df['Review'].apply(remove_number)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
# remove single char
def remove_singl_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

df['Review'] = df['Review'].apply(remove_singl_char)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
# NLTK word rokenize 
def word_tokenize_wrapper(text):
    return word_tokenize(text)

df['tokenization'] = df['Review'].apply(word_tokenize_wrapper)
df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
#                                                  Review  Rating  \
# 10                                        enak kuacinya       5
# 12    pengiriman cepat packing bagus sesuai pesanan ...       5
# 13    pengemasan luar biasa baik untuk rasa menurut ...       4
# 15                                      terimakasih min       5
# 16                   udah order untuk kesekian kali jos       5
# ...                                                 ...     ...
# 5421  seller sangat responsif rasa belum dicoba kare...       5
# 5422                           imut banget packing aman       5
# 5423                        good product trusted seller       5
# 5424                                  sudah beli yg ke        5
# 5425                                    byk campurannya       4
#
#                                            tokenization
# 10                                     [enak, kuacinya]
# 12    [pengiriman, cepat, packing, bagus, sesuai, pe...
# 13    [pengemasan, luar, biasa, baik, untuk, rasa, m...
# 15                                   [terimakasih, min]
# 16            [udah, order, untuk, kesekian, kali, jos]
# ...                                                 ...
# 5421  [seller, sangat, responsif, rasa, belum, dicob...
# 5422                      [imut, banget, packing, aman]
# 5423                   [good, product, trusted, seller]
# 5424                              [sudah, beli, yg, ke]
# 5425                                 [byk, campurannya]
#
# [4060 rows x 3 columns]

# %%
normalizad_word = pd.read_csv("/content/list fix misleading words.csv")

# %%
normalizad_word.drop("0", axis=1, inplace=True)

# %%
normalizad_word
# Out:
#           then                 new
# 0        seler             penjual
# 1           yg                yang
# 2      packing          pengemasan
# 3       respon             respons
# 4        order                beli
# ...        ...                 ...
# 1045    ontime         tepat waktu
# 1046   on time         tepat waktu
# 1047  everyone        setiap orang
# 1048   familys            keluarga
# 1049       gbu  tuhan memberkatimu
#
# [1050 rows x 2 columns]

# %%
normalizad_word.isnull().sum()
# Out:
# then     0
# new     13
# dtype: int64

# %%
normalizad_word = normalizad_word.dropna()

# %%
normalizad_word.isnull().sum()
# Out:
# then    0
# new     0
# dtype: int64

# %%
#Normalized text
normalizad_word_dict = {}

for index, row in normalizad_word.iterrows():
    if row[0] not in normalizad_word_dict:
        normalizad_word_dict[row[0]] = row[1] 

def normalized_term(document):
    return [normalizad_word_dict[term] if term in normalizad_word_dict else term for term in document]

df['Review_Normalized'] = df['tokenization'].apply(normalized_term)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()

# %%
df
# Out:
#                                                  Review  Rating  \
# 10                                        enak kuacinya       5
# 12    pengiriman cepat packing bagus sesuai pesanan ...       5
# 13    pengemasan luar biasa baik untuk rasa menurut ...       4
# 15                                      terimakasih min       5
# 16                   udah order untuk kesekian kali jos       5
# ...                                                 ...     ...
# 5421  seller sangat responsif rasa belum dicoba kare...       5
# 5422                           imut banget packing aman       5
# 5423                        good product trusted seller       5
# 5424                                  sudah beli yg ke        5
# 5425                                    byk campurannya       4
#
#                                            tokenization  \
# 10                                     [enak, kuacinya]
# 12    [pengiriman, cepat, packing, bagus, sesuai, pe...
# 13    [pengemasan, luar, biasa, baik, untuk, rasa, m...
# 15                                   [terimakasih, min]
# 16            [udah, order, untuk, kesekian, kali, jos]
# ...                                                 ...
# 5421  [seller, sangat, responsif, rasa, belum, dicob...
# 5422                      [imut, banget, packing, aman]
# 5423                   [good, product, trusted, seller]
# 5424                              [sudah, beli, yg, ke]
# 5425                                 [byk, campurannya]
#
#                                       Review_Normalized
# 10                                     [enak, kuacinya]
# 12    [pengiriman, cepat, pengemasan, bagus, sesuai,...
# 13    [pengemasan, luar, biasa, baik, untuk, rasa, m...
# 15                              [terima kasih, minimal]
# 16         [sudah, beli, untuk, kesekian, kali, mantap]
# ...                                                 ...
# 5421  [seller, sangat, responsif, rasa, belum, dicob...
# 5422                   [imut, banget, pengemasan, aman]
# 5423                  [good, produk, dipercaya, seller]
# 5424                            [sudah, beli, yang, ke]
# 5425                              [banyak, campurannya]
#
# [4060 rows x 4 columns]

# %%
# import Sastrawi package
# !pip install Sastrawi
# !pip install swifter
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter
# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['Review_Normalized']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]

df['df_token_stemm'] = df['Review_Normalized'].swifter.apply(get_stemmed_term)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: Sastrawi in /usr/local/lib/python3.7/dist-packages (1.0.1)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: swifter in /usr/local/lib/python3.7/dist-packages (1.2.0)
# Requirement already satisfied: parso>0.4.0 in /usr/local/lib/python3.7/dist-packages (from swifter) (0.8.3)
# Requirement already satisfied: bleach>=3.1.1 in /usr/local/lib/python3.7/dist-packages (from swifter) (5.0.1)
# Requirement already satisfied: tqdm>=4.33.0 in /usr/local/lib/python3.7/dist-packages (from swifter) (4.64.0)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from swifter) (1.3.5)
# Requirement already satisfied: psutil>=5.6.6 in /usr/local/lib/python3.7/dist-packages (from swifter) (5.9.1)
# Requirement already satisfied: cloudpickle>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from swifter) (1.3.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in /usr/local/lib/python3.7/dist-packages (from swifter) (7.7.1)
# Requirement already satisfied: dask[dataframe]>=2.10.0 in /usr/local/lib/python3.7/dist-packages (from swifter) (2.12.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from bleach>=3.1.1->swifter) (1.15.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from bleach>=3.1.1->swifter) (0.5.1)
# Requirement already satisfied: toolz>=0.7.3 in /usr/local/lib/python3.7/dist-packages (from dask[dataframe]>=2.10.0->swifter) (0.12.0)
# Requirement already satisfied: numpy>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from dask[dataframe]>=2.10.0->swifter) (1.21.6)
# Requirement already satisfied: partd>=0.3.10 in /usr/local/lib/python3.7/dist-packages (from dask[dataframe]>=2.10.0->swifter) (1.2.0)
# Requirement already satisfied: fsspec>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from dask[dataframe]>=2.10.0->swifter) (2022.5.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->swifter) (3.6.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->swifter) (4.10.1)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->swifter) (5.1.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->swifter) (0.2.0)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->swifter) (5.5.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->swifter) (1.1.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.7/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (5.3.5)
# Requirement already satisfied: tornado>=4.0 in /usr/local/lib/python3.7/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (5.1.1)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (1.0.18)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.8.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (57.4.0)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (2.6.1)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (4.8.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.7.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.0.0->swifter) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.0.0->swifter) (2022.1)
# Requirement already satisfied: locket in /usr/local/lib/python3.7/dist-packages (from partd>=0.3.10->dask[dataframe]>=2.10.0->swifter) (1.0.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.7/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (5.3.1)
# Requirement already satisfied: jupyter-core>=4.4.0 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (4.11.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (2.11.3)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (5.4.0)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.13.3)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (1.8.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (5.6.1)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.7/dist-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (23.2.0)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.7/dist-packages (from terminado>=0.8.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.7.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (2.0.1)
# Requirement already satisfied: testpath in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.6.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (1.5.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.4)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.8.4)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.7/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (4.3.3)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.7/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (2.16.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.18.1)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (21.4.0)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (5.8.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (4.1.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (4.12.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.7/dist-packages (from importlib-resources>=1.4.0->jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (3.8.1)
# 4044
# ------------------------
# enak : enak
# kuacinya : kuaci
# pengiriman : kirim
# cepat : cepat
# pengemasan : emas
# bagus : bagus
# sesuai : sesuai
# pesanan : pesan
# belum : belum
# di : di
# coba : coba
# terima : terima
# kasih : kasih
# luar : luar
# biasa : biasa
# baik : baik
# untuk : untuk
# rasa : rasa
# menurut : turut
# saya : saya
# lebih : lebih
# dominan : dominan
# ke : ke
# asli : asli
# atau : atau
# mau : mau
# varian : varian
# apapun : apa
# soalnya : soal
# rasanya : rasa
# kurang : kurang
# dan : dan
# sedikit : sedikit
# asin : asin
# juga : juga
# yang : yang
# agak : agak
# terasa : asa
# itu : itu
# rumput : rumput
# laut : laut
# lain : lain
# nya : nya
# mendominasi : dominasi
# sih : sih
# terima kasih : terima kasih
# minimal : minimal
# sudah : sudah
# beli : beli
# kesekian : sekian
# kali : kali
# mantap : mantap
# enaak : enaak
# guriih : guriih
# kacang : kacang
# respons : respons
# harga : harga
# terjangkau : jangkau
# mantappppp : mantappppp
# recommended : recommended
# empingnya : emping
# enakkkkk : enakkkkk
# mantapppp : mantapppp
# puas : puas
# gurih : gurih
# banget : banget
# nanti : nanti
# pesan : pesan
# lagi : lagi
# kesukaan : suka
# kondisi : kondisi
# kurir : kurir
# mdhan : mdhan
# rekomendasi : rekomendasi
# renyah : renyah
# rapi : rapi
# lanjut : lanjut
# seller : seller
# tokopedia : tokopedia
# segar : segar
# bermutu : mutu
# tumben : tumben
# dari : dari
# biasanya : biasa
# hehe : hehe
# kepingin : kepingin
# makan : makan
# keripik : keripik
# pedas : pedas
# aaaa : aaaa
# sangat : sangat
# buat : buat
# dijadiin : dijadiin
# snack : snack
# makasihh : makasihh
# ini : ini
# terus : terus
# naujubillah : naujubillah
# tapi : tapi
# ketagihan : tagih
# walaupun : walaupun
# mencret : mencret
# kapok : kapok
# teman : teman
# sok : sok
# sokan : sok
# mencoba : coba
# sampai : sampai
# semua : semua
# lengkap : lengkap
# langganan : langgan
# sejati : sejati
# sukses : sukses
# riki : riki
# terjamin : jamin
# pedasnya : pedas
# gurihnya : gurih
# pas : pas
# cuma : cuma
# tidak : tidak
# berasa : asa
# singkong : singkong
# saran : saran
# saja : saja
# kalau : kalau
# pembelian : beli
# bungkus : bungkus
# ada : ada
# bonus : bonus
# biar : biar
# makin : makin
# lariss : lariss
# selalu : selalu
# panas : panas
# perut : perut
# ge : ge
# pengirimannya : kirim
# aman : aman
# baso : baso
# acinya : aci
# serius : serius
# teksturnya : tekstur
# kaca : kaca
# khad : khad
# garut : garut
# isian : isi
# ayamnya : ayam
# barang : barang
# benerannagih : benerannagih
# kuah : kuah
# pokoknya : pokok
# manteppppp : manteppppp
# mantapp : mantapp
# kualitass : kualitass
# lumayan : lumayan
# cepatt : cepatt
# terimakasii : terimakasii
# toko : toko
# nyaaaa : nyaaaa
# dalam : dalam
# keadaan : ada
# pilus : pilus
# cikur : cikur
# alot : alot
# lihat : lihat
# lama : lama
# paket : paket
# diberi : beri
# pcs : pcs
# aci : aci
# isi : isi
# kecil : kecil
# porsi : porsi
# banyak : banyak
# baru : baru
# kemarin : kemarin
# hari : hari
# produk : produk
# dengan : dengan
# selamat : selamat
# rusak : rusak
# premium : premium
# alhamdulillah : alhamdulillah
# habis : habis
# bisa : bisa
# berhenti : henti
# ginian : ginian
# terbuka : buka
# kemasannya : kemas
# untung : untung
# masih : masih
# pelit : pelit
# bumbunya : bumbu
# belanja : belanja
# disini : sini
# kangen : kangen
# terbayarkan : bayar
# pagi : pagi
# sekali : sekali
# dikirim : kirim
# malam : malam
# patut : patut
# dapat : dapat
# bintang : bintang
# telurnya : telur
# garing : garing
# bubble : bubble
# pembungkus : bungkus
# telur : telur
# medan : medan
# datang : datang
# responsif : responsif
# pakai : pakai
# enaaaakk : enaaaakk
# harapan : harap
# ok : ok
# ya : ya
# ueennaakkk : ueennaakkk
# sellernya : sellernya
# kamu : kamu
# yah : yah
# diproses : proses
# deskripsi : deskripsi
# penjual : jual
# rencana : rencana
# lebaran : lebaran
# ternyata : nyata
# nggak : nggak
# ter : ter
# semoga : moga
# tengik : tengik
# sellu : sellu
# perlu : perlu
# diperbaiki : baik
# penjualnya : jual
# ramah : ramah
# berkah : berkah
# gag : gag
# sabar : sabar
# proses : proses
# jam : jam
# langsung : langsung
# waktu : waktu
# sukaaaa : sukaaaa
# nyasar : nyasar
# hari yang sama : hari yang sama
# jadi : jadi
# produknya : produk
# oke : oke
# good : good
# sayang : sayang
# admin : admin
# huhuu : huhuu
# maaf : maaf
# cuankie : cuankie
# segel : segel
# karena : karena
# tipis : tipis
# lah : lah
# akhir : akhir
# ditunggu : tunggu
# diterima : terima
# tahu : tahu
# puasa : puasa
# proteksinya : proteksi
# diacungi : acung
# jempol : jempol
# bukan : bukan
# kw : kw
# juragan : juragan
# ajah : ajah
# usah : usah
# jauh : jauh
# kemalang : malang
# dipakai : pakai
# kripiknya : kripiknya
# satu : satu
# persatu : satu
# dimskkan : dimskkan
# kardus : kardus
# dong : dong
# tanggapan : tanggap
# betul : betul
# sekarang : sekarang
# keripiknya : keripik
# tebal : tebal
# keras : keras
# butuh : butuh
# tenaga : tenaga
# ekstra : ekstra
# gigitnya : gigit
# beda : beda
# sama : sama
# dulu : dulu
# ngomong-ngomong : ngomong-ngomong
# packingannya : packingannya
# super : super
# masing : masing
# item : item
# dicoba : coba
# menyesal : sesal
# gr : gr
# bangett : bangett
# empuk : empuk
# melempem : melempem
# memuaskan : muas
# gosongnyaa : gosongnyaa
# mede : mede
# nyaaa : nyaaa
# repeat : repeat
# sekian : sekian
# kalinya : kali
# kardusnya : kardus
# basah : basah
# kena : kena
# hujan : hujan
# mudahan : mudah
# harus : harus
# dipercepat : cepat
# jagung : jagung
# bakar : bakar
# nori : nori
# klop : klop
# unik : unik
# digoreng : goreng
# patah : patah
# ikannya : ikan
# padahal : padahal
# frezer : frezer
# sehingga : sehingga
# bandeng : bandeng
# terlalu : terlalu
# cukup : cukup
# free : free
# ongkir : ongkir
# lo : lo
# pelayanan : layan
# on : on
# nikmat : nikmat
# pelayanannya : layan
# prima : prima
# top : top
# jangan : jangan
# ragu : ragu
# lho : lho
# orang : orang
# yaa : yaa
# ulang : ulang
# orderke : orderke
# enakk : enakk
# cocokk : cocokk
# ownernya : ownernya
# duper : duper
# kualitas : kualitas
# bakal : bakal
# mbak : mbak
# cantik : cantik
# mahal : mahal
# sebanding : banding
# amut : amut
# membantu : bantu
# komunikasi : komunikasi
# siang : siang
# katanya : kata
# suka : suka
# pemjual : pemjual
# akan : akan
# pasti : pasti
# nasi : nasi
# jeruknya : jeruk
# makanan : makan
# terbaik : baik
# paling : paling
# dibanding : banding
# sejenis : jenis
# ngga : ngga
# enek : enek
# full : full
# baked : baked
# bumil : bumil
# notes : notes
# dipastiin : dipastiin
# matang : matang
# hamil : hamil
# salmonnya : salmon
# mentah : mentah
# bismillah : bismillah
# tidak apa : tidak apa
# tolong : tolong
# saus : saus
# mentainya : mentainya
# melimpah : limpah
# ruah : ruah
# jakarta : jakarta
# entah : entah
# kenapa : kenapa
# sebelumnya : belum
# pernah : pernah
# beliin : beliin
# dia : dia
# salmon : salmon
# mentai : mentai
# tempat : tempat
# kerja : kerja
# momomaru : momomaru
# salah : salah
# hanya : hanya
# chicken : chicken
# katsu : katsu
# tahun : tahun
# lalu : lalu
# minta : minta
# saat : saat
# bareng : bareng
# ongkirnya : ongkirnya
# lebihin : lebihin
# bayar : bayar
# utang : utang
# deket : deket
# lidah : lidah
# ndeso : ndeso
# dimakan : makan
# tadi : tadi
# barat : barat
# setengah : tengah
# sore : sore
# hangat : hangat
# hangatkan : hangat
# microwave : microwave
# kimcinya : kimcinya
# asam : asam
# samwon : samwon
# resto : resto
# memang : memang
# terkenal : kenal
# para : para
# expat : expat
# korean : korean
# ttg : ttg
# gimana : gimana
# kedua : dua
# kg : kg
# malah : malah
# plastik : plastik
# vakum : vakum
# bocor : bocor
# sedih : sedih
# air : air
# kimchi : kimchi
# jiggae : jiggae
# bangattt : bangattt
# seperti : seperti
# pahit : pahit
# asemnya : asemnya
# kurangi : kurang
# dekat : dekat
# menyenangkan : senang
# profesional : profesional
# sipppp : sipppp
# beli lagi : beli lagi
# termurah : murah
# lumpia : lumpia
# semarang : semarang
# posisinya : posisi
# pun : pun
# terjaga : jaga
# tepat : tepat
# komunikatif : komunikatif
# beberapa : beberapa
# kemasan : kemas
# jml : jml
# kebetulan : betul
# beseknya : besek
# dilihat : lihat
# ukuraya : ukuraya
# mkin : mkin
# kcl : kcl
# tetap : tetap
# mempertahankan : tahan
# kwlitas : kwlitas
# gojek : gojek
# tokped : tokped
# kecewa : kecewa
# cocok : cocok
# mengobati : obat
# josh : josh
# gandhosss : gandhosss
# tunggu : tunggu
# buka : buka
# kiriman : kirim
# masam : masam
# ny : ny
# minil : mil
# praktis : praktis
# dimakannya : makan
# ditingkatkan : tingkat
# bad : bad
# pahitnya : pahit
# euyy : euyy
# warna : warna
# kartu : kartu
# ucapan : ucap
# gelap : gelap
# kelihatan : lihat
# ditulis : tulis
# bahan : bahan
# kertas : kertas
# sulit : sulit
# overall : overall
# kok : kok
# brownies : brownies
# enakkk : enakkk
# lembut : lembut
# chewy : chewy
# dark : dark
# cokelat : cokelat
# manis : manis
# doang : doang
# kismis : kismis
# sentosa : sentosa
# lucu : lucu
# desain : desain
# beruang : beruang
# pantatnya : pantat
# wkwkwk : wkwkwk
# bearly : bearly
# baker : baker
# sorry : sorry
# bawel : bawel
# chat : chat
# aku : aku
# punya : punya
# fotonya : foto
# yummy : yummy
# kirim : kirim
# maghrib : maghrib
# pesennya : sen
# hehehe : hehehe
# bearlybaker : bearlybaker
# sukaa : sukaa
# in : in
# kota : kota
# kue : kue
# sepertinya : seperti
# dikartunya : kartu
# lupa : lupa
# to : to
# from : from
# dicatatan : catat
# lainnya : lain
# kotak : kotak
# kemas : kemas
# paper : paper
# bag : bag
# juara : juara
# sea : sea
# saltnya : saltnya
# sensasi : sensasi
# asik : asik
# favorit : favorit
# the : the
# diva : diva
# enaaak : enaaak
# keponakan : keponakan
# kebagian : bagi
# cookies : cookies
# enaaakkk : enaaakkk
# obat : obat
# maap : maap
# sempat : sempat
# foto : foto
# ulasan : ulas
# sahur : sahur
# meresap : resap
# anak : anak
# ku : ku
# makanannya : makan
# rumahan : rumah
# nambah : nambah
# menunya : menu
# dagingnya : daging
# lunaknya : lunak
# sering : sering
# sini : sini
# masakannya : masakan
# bonusnya : bonus
# masakan : masakan
# selera : selera
# kita : kita
# mohon : mohon
# pertahankan : tahan
# ayam : ayam
# gorengnya : goreng
# bumbu : bumbu
# serundeng : serundeng
# laosnya : laos
# nd : nd
# cepaaat : cepaaat
# pendamping : damping
# lokasi : lokasi
# berdekatan : dekat
# benar : benar
# kecutttt : kecutttt
# bangetttt : bangetttt
# tipe : tipe
# kecut : kecut
# keluarga : keluarga
# diabet : abet
# rumah : rumah
# sungguh : sungguh
# sekalii : sekali
# besok : besok
# tujuan : tuju
# meletus : letus
# tekanan : tekan
# gas : gas
# siap : siap
# keburu : keburu
# duluan : duluan
# bagian : bagi
# dalamnya : dalam
# pingin : pingin
# cobain : cobain
# hihihiii : hihihiii
# telah : telah
# kami : kami
# ekspedisi : ekspedisi
# antar : antar
# menggunakan : guna
# jasa : jasa
# tanggal : tanggal
# track : track
# tggl : tggl
# menuju : tuju
# diantar : antar
# pembeli : beli
# itupun : itu
# telepon : telepon
# pelayan : layan
# responnya : responnya
# bantu : bantu
# laporkan : lapor
# kak : kak
# ditgg : ditgg
# terucap : ucap
# memaki : maki
# pesawat : pesawat
# kembali : kembali
# makassar : makassar
# komplain : komplain
# akhirnya : akhir
# terburu : buru
# sipp : sipp
# sellee : sellee
# shopee : shopee
# berbicara : bicara
# deh : deh
# green : green
# tea : tea
# recommend : recommend
# surprisingly : surprisingly
# asem : asem
# sopan : sopan
# berlebihan : lebih
# lokal : lokal
# swalayan : swalayan
# kebanyakan : banyak
# plastiknya : plastik
# pecah : pecah
# mungkin : mungkin
# kesalahan : salah
# ditangani : tangan
# masalah : masalah
# tumpah : tumpah
# okelah : oke
# belanjanya : belanja
# lapaknya : lapak
# mimin : mimin
# mengirimnya : kirim
# ending : ending
# campuran : campur
# ataupun : atau
# camilan : camil
# sisss : sisss
# was : was
# proper : proper
# wrapped : wrapped
# really : really
# will : will
# it : it
# sure : sure
# ternama : nama
# mengecewakan : kecewa
# tokonya : toko
# menjaga : jaga
# layanan : layan
# teri : teri
# lmaa : lmaa
# jika : jika
# gambar : gambar
# makasssssiiihhhh : makasssssiiihhhh
# abiz : abiz
# ovennya : oven
# minyak : minyak
# lanang : lanang
# belinya : beli
# bangettt : bangettt
# usual : usual
# spesial : spesial
# bu : bu
# rudy : rudy
# meski : meski
# seminggu : minggu
# terinya : teri
# tetapi : tetapi
# biru : biru
# pink : pink
# otak : otak
# alhamdulillaah : alhamdulillaah
# potong : potong
# es : es
# mencair : cair
# total : total
# bandengnya : bandeng
# ketika : ketika
# dibuka : buka
# berlendir : lendir
# kepanasan : panas
# kelamaan : lama
# minggu : minggu
# kejadian : jadi
# styrofoam : styrofoam
# zzzzzzzzzzz : zzzzzzzzzzz
# pelapak : lapak
# beresssss : beresssss
# dendeng : dendeng
# mantaaaaaapppp : mantaaaaaapppp
# bbrp : bbrp
# enakkkkkkk : enakkkkkkk
# pak : pak
# tuhan memberkatimu : tuhan berkat
# tuhan : tuhan
# yesus : yesus
# memberkati : kati
# amin : amin
# buangettttt : buangettttt
# sapi : sapi
# natal : natal
# kadaluarsa : kadaluarsa
# dikasinya : kas
# juli : juli
# apek : apek
# sebelum : belum
# kos : kos
# dikonsumsi : konsumsi
# sendiri : sendiri
# keterangan : terang
# bbq : bbq
# sedap : sedap
# ikan : ikan
# baiik : baiik
# orang tua : orang tua
# baiikk : baiikk
# sellau : sellau
# kesenangan : senang
# tambah : tambah
# pelanggan : langgan
# dicemil : dicemil
# kering : kering
# tempenya : tempe
# labelnya : label
# prosesnya : proses
# apa : apa
# bau : bau
# amis : amis
# photo : photo
# cakep : cakep
# dimasak : masak
# sesuia : sesuia
# gaada : gaada
# sampesuka : sampesuka
# salad : salad
# nyaa : nyaa
# saladnya : saladnya
# kuahnya : kuah
# suuuukkkkaaaaa : suuuukkkkaaaaa
# mantulll : mantulll
# akuratt : akuratt
# patent : patent
# excellence : excellence
# ciamik : ciamik
# buah : buah
# terenak : enak
# rasanyapromonya : rasanyapromonya
# promo : promo
# seenak : enak
# mantaaaappppp : mantaaaappppp
# uwenaaakkk : uwenaaakkk
# pesannya : pesan
# keju : keju
# coklat : coklat
# serahkan : serah
# penerima : terima
# lambat : lambat
# kartika : kartika
# sari : sari
# neh : neh
# psg : psg
# molennya : molennya
# sicepat : sicepat
# istri : istri
# hampers : hampers
# ramadhan : ramadhan
# ampunnn : ampunnn
# bngettt : bngettt
# sambal : sambal
# enakkkk : enakkkk
# tercepat : cepat
# se : se
# asia : asia
# tenggara : tenggara
# sei : sei
# berkali : kali
# nih : nih
# sambelnya : sambelnya
# maha : maha
# dahsyat : dahsyat
# wagyu : wagyu
# kelas : kelas
# nice : nice
# perfecto : perfecto
# agan : agan
# boss : boss
# dijamin : jamin
# bossque : bossque
# namun : namun
# setelah : telah
# puassssssssssssss : puassssssssssssss
# pacarku : pacar
# pisangnya : pisang
# jumat : jumat
# senin : senin
# sabtu : sabtu
# libur : libur
# selasa : selasa
# penampilan : tampil
# kereeen : kereeen
# bgtt : bgtt
# ldr : ldr
# tumpeng : tumpeng
# pada : pada
# bilang : bilang
# yaaa : yaaa
# tampilan : tampil
# tumpengnya : tumpeng
# tepat waktu : tepat waktu
# enaaaaak : enaaaaak
# ambil : ambil
# dadakan : dada
# hiasan : hias
# pilih : pilih
# lancar : lancar
# korporatif : korporatif
# senang : senang
# briyani : briyani
# diragukan : ragu
# etalase : etalase
# murah : murah
# persediaan : sedia
# kutunya : kutu
# kuat : kuat
# kuningnya : kuning
# cantik enak : cantik enak
# recommened : recommened
# lezattt : lezattt
# pengalaman : alam
# online : online
# berkesan : kesan
# lauk : lauk
# pauknya : pauk
# atas : atas
# srvis : srvis
# timm : timm
# catering : catering
# acara : acara
# des : des
# lauknya : lauk
# goreng : goreng
# kuning : kuning
# ati : ati
# ampla : ampla
# perkedel : perkedel
# urap : urap
# sayur : sayur
# balado : balado
# orek : orek
# tempe : tempe
# sambalnya : sambal
# penataannya : tata
# menarik : tarik
# garnishnya : garnishnya
# kreatif : kreatif
# bunga : bunga
# cabe : cabe
# tulisan : tulis
# wortel : wortel
# wangi : wangi
# transparan : transparan
# keselurahan : selurah
# terutama : utama
# legit : legit
# cabenya : cabe
# laukpauknya : laukpauknya
# diatas : atas
# term : term
# recomeneddd : recomeneddd
# pollnasi : pollnasi
# pulen : pulen
# urapnya : urap
# tahan : tahan
# empal : empal
# enakresponnya : enakresponnya
# permintaan : minta
# happy : happy
# blackstone : blackstone
# ukurannya : ukur
# kenyang : kenyang
# nasinya : nasi
# mantaappp : mantaappp
# pilihan : pilih
# perhitungan : hitung
# masuk : masuk
# akal : akal
# awalnya : awal
# tanya : tanya
# sekolahan : sekolah
# rb : rb
# kiri : kiri
# sebelahan : belah
# sekolah : sekolah
# masukan : masuk
# mini : mini
# untungnya : untung
# sumpah : sumpah
# ahh : ahh
# pudingnya : puding
# diberikan : beri
# puding : puding
# lalapannya : lalap
# besoknya : besok
# ditambah : tambah
# janji : janji
# kantor : kantor
# penerimanya : terima
# nunggu : nunggu
# pulang : pulang
# ketepatan : tepat
# penting : penting
# diperhatikan : perhati
# segitu : segitu
# ajip : ajip
# pula : pula
# pokonya : poko
# gitu : gitu
# khusus : khusus
# bulan : bulan
# berikutnya : ikut
# mininya : mini
# pudingnyaa : pudingnyaa
# datangnya : datang
# menu : menu
# apalagi : apalagi
# maknyoooss : maknyoooss
# pertama : pertama
# owner : owner
# cuman : cuman
# yaitu : yaitu
# anteraja : anteraja
# berharap : harap
# estemasinya : estemasinya
# keseratus : ratus
# wkkwkw : wkkwkw
# hadiah : hadiah
# motor : motor
# langgananan : langgananan
# bingung : bingung
# gosong : gosong
# kotor : kotor
# bicara : bicara
# tekstur : tekstur
# usia : usia
# basi : basi
# adem : adem
# pantesan : pantesan
# tinggal : tinggal
# masak : masak
# seh : seh
# teenyata : teenyata
# instan : instan
# terasi : terasi
# merek : merek
# uleg : uleg
# finna : finna
# esok : esok
# harinya : hari
# pengirimanny : pengirimanny
# mantaap : mantaap
# rasanyaa : rasanyaa
# konsisten : konsisten
# semenjak : semenjak
# pindah : pindah
# surabaya : surabaya
# rapat : rapat
# mantabss : mantabss
# wrapping : wrapping
# sebagus : bagus
# toplesnya : toplesnya
# lapis : lapis
# tingkatkan : tingkat
# harusnya : harus
# dibawa : bawa
# keluar : keluar
# bos : bos
# solusi : solusi
# darurat : darurat
# sumatra : sumatra
# otaji : otaji
# imut : imut
# kotaknya : kotak
# hampir : hampir
# begitu : begitu
# pengirim : kirim
# dibanyakin : dibanyakin
# jujur : jujur
# tadinya : tadi
# gamau : gamau
# ngasih : ngasih
# jelek : jelek
# kosong : kosong
# dikasih : kasih
# bakso : bakso
# cuanki : cuanki
# maklumin : maklumin
# kabar : kabar
# tanyain : tanyain
# keesokan : esok
# eh : eh
# kan : kan
# mba : mba
# terbungkus : bungkus
# namanya : nama
# po : po
# bawah : bawah
# cuangki : cuangki
# lebak : lebak
# bulus : bulus
# sihh : sihh
# bikinnya : bikin
# selebihnya : lebih
# biarlah : biar
# bosque : bosque
# baksonya : bakso
# bns : bns
# tambahan : tambah
# ni : ni
# wkwkwkw : wkwkwkw
# its : its
# all : all
# keep : keep
# up : up
# makananya : makananya
# lezzattoooo : lezzattoooo
# kirimanya : kirimanya
# express : express
# pizza : pizza
# enaaakk : enaaakk
# menjelang : jelang
# jarak : jarak
# sekitar : sekitar
# km : km
# tasty : tasty
# cheese : cheese
# rotinya : roti
# berimbang : imbang
# cheesenya : cheesenya
# tiramisu : tiramisu
# disusul : susul
# jadinya : jadi
# double : double
# aamiin : aamiin
# kurangbagus : kurangbagus
# jumlahnya : jumlah
# tidak tahu : tidak tahu
# berapa : berapa
# pedas sekali : pedas sekali
# kulitnya : kulit
# sejujurnya : jujur
# pinpoint : pinpoint
# segi : segi
# maupun : maupun
# coipan : coipan
# coipannya : coipannya
# bawang : bawang
# putihnya : putih
# of : of
# choipans : choipans
# secara : cara
# kulit : kulit
# choipannya : choipannya
# choipan : choipan
# krenyes : krenyes
# bangettttt : bangettttt
# cucok : cucok
# akuu : akuu
# hihihih : hihihih
# kakak : kakak
# hati : hati
# kentangnya : kentang
# menit : menit
# ikutan : ikut
# flash : flash
# jual : jual
# tomat : tomat
# ceri : ceri
# sayuran : sayur
# rbu : rbu
# sayurannya : sayur
# topping : topping
# kn : kn
# bebas : bebas
# nambahin : nambahin
# irisan : iris
# tuna : tuna
# daging : daging
# dll : dll
# saosnya : saosnya
# ampuuun : ampuuun
# sayurnya : sayur
# bersahabat : sahabat
# icip : icip
# menanyakan : tanya
# tingkat : tingkat
# saudara : saudara
# segini : gin
# juicenya : juicenya
# yummyyyyy : yummyyyyy
# jualannya : jual
# laris : laris
# ttp : ttp
# bosan : bosan
# diantara : antara
# percaya : percaya
# id : id
# is : is
# tercium : cium
# baunya : bau
# harang : harang
# lobak : lobak
# pkknya : pkknya
# rasanyapengiriman : rasanyapengiriman
# toples : toples
# enyakkkk : enyakkkk
# korea : korea
# sekilas : kilas
# sengaja : sengaja
# supaya : supaya
# atur : atur
# kadar : kadar
# keasaman : asam
# berikut : ikut
# sehat : sehat
# probiotik : probiotik
# alami : alami
# drama : drama
# aromanya : aroma
# dressingnya : dressingnya
# mengenyangkan : kenyang
# dua : dua
# potongan : potong
# tortilla : tortilla
# isiannya : isi
# padat : padat
# kaya : kaya
# dressing : dressing
# madu : madu
# mustard : mustard
# prefer : prefer
# dikemas : kemas
# sauce : sauce
# dilapisi : lapis
# bentuknya : bentuk
# wasabi : wasabi
# pesto : pesto
# bahannya : bahan
# tampilannya : tampil
# mantappp : mantappp
# ukuran : ukur
# besar : besar
# bagi : bagi
# ditanya : tanya
# serasa : serasa
# diskon : diskon
# hehee : hehee
# gaboong : gaboong
# indo : indo
# fermentasinya : fermentasi
# klamaan : klamaan
# si : si
# ntaps : ntaps
# ramyeon : ramyeon
# pa : pa
# selain : selain
# timun : timun
# sawi : sawi
# jajang : jajang
# teus : teus
# pemesanan : mesan
# terakhir : akhir
# zonk : zonk
# dijalan : jalan
# kooperatif : kooperatif
# ganti : ganti
# membayar : bayar
# kemanisan : manis
# sekaliii : sekaliii
# food : food
# simpan : simpan
# fermentasi : fermentasi
# dl : dl
# setidaknya : tidak
# enaakkkk : enaakkkk
# yummyyy : yummyyy
# diatur : atur
# menyesuaikan : sesuai
# kurangnya : kurang
# campur : campur
# kantong : kantong
# hitam : hitam
# dingin : dingin
# diajak : ajak
# urgent : urgent
# sorenya : sore
# lau : lau
# takut : takut
# older : older
# kakaknya : kakak
# baiknya : baik
# bless : bless
# srkali : srkali
# pedia : dia
# freshh : freshh
# asamnya : asam
# muehehehehehe : muehehehehehe
# pedesnyaa : pedesnyaa
# aduh : aduh
# lamaa : lamaa
# loh : loh
# koto : koto
# beliseger : beliseger
# cabbage : cabbage
# dipisah : pisah
# dicampurin : dicampurin
# sangking : sangking
# ssdihnya : ssdihnya
# dilain : lain
# huhuuuu : huhuuuu
# volumenya : volume
# rembes : rembes
# reseler : reseler
# kebocoran : bocor
# cuka : cuka
# dikulkas : kulkas
# tersegar : segar
# menurutku : turut
# kira : kira
# dibagi : bagi
# menjadi : jadi
# per : per
# sesampainya : sampa
# dirumah : rumah
# menggembung : gembung
# susah : susah
# meledak : ledak
# selama : lama
# perjalanan : jalan
# guncangan : guncang
# kehilangan : hilang
# dosisnya : dosis
# nyiahahha : nyiahahha
# mah : mah
# ngembang : ngembang
# wkwkw : wkwkw
# gram : gram
# dapatnya : dapat
# okeyyy : okeyyy
# respone : respone
# jepang : jepang
# pengobat : obat
# rindu : rindu
# homemade : homemade
# gakaruan : gakaruan
# mending : mending
# sakit : sakit
# kamis : kamis
# email : email
# dibubble : dibubble
# dalemnya : dalem
# wadah : wadah
# utuh : utuh
# retak : retak
# nutup : nutup
# diisolasi : isolasi
# lakban : lakban
# bolong : bolong
# olshop : olshop
# diorder : order
# sukaaaaaaaaaaaaa : sukaaaaaaaaaaaaa
# supperrrrrrr : supperrrrrrr
# okehh : okehh
# aampe : aampe
# ngakak : ngakak
# ngebalonnnn : ngebalonnnn
# superrrr : superrrr
# gazzy : gazzy
# pop : pop
# anginnya : angin
# meledakkk : meledakkk
# jalan : jalan
# bogor : bogor
# luarnya : luar
# sealed : sealed
# gituhh : gituhh
# dapursakinahku : dapursakinahku
# membasahi : basah
# seharusnya : harus
# maksimal : maksimal
# maret : maret
# oleh : oleh
# konsumen : konsumen
# dikirimkan : kirim
# pihak : pihak
# alasan : alas
# dihitung : hitung
# sistem : sistem
# sunggung : sunggung
# lontongnya : lontong
# daun : daun
# pakainopor : pakainopor
# mendadak : dadak
# opor : opor
# sisa : sisa
# lontong : lontong
# kompetitor : kompetitor
# lembutnya : lembut
# benyek : benyek
# om : om
# kejel : jel
# ujungnya : ujung
# lembek : lembek
# hancur : hancur
# oncom : oncom
# oncomnya : oncom
# tebalnya : tebal
# separuh : paruh
# affordable : affordable
# definitely : definitely
# tanggap : tanggap
# mexican : mexican
# pengantaran : antar
# however : however
# little : little
# salads : salads
# portion : portion
# amanah : amanah
# anterajanya : anterajanya
# mengirim : kirim
# anterajaanternya : anterajaanternya
# kapan : kapan
# asinannya : asin
# yummmmyyyyyy : yummmmyyyyyy
# fresssshhhhh : fresssshhhhh
# asinan : asin
# ingredients : ingredients
# perpaduan : padu
# mangga : mangga
# lengkeng : lengkeng
# deeeh : deeeh
# amiiin : amiiin
# cream : cream
# durian : durian
# joooss : joooss
# gratis : gratis
# jossss : jossss
# eeeeehhh : eeeeehhh
# buahnya : buah
# mayoinase : mayoinase
# buahannya : buah
# sausnya : saus
# kewpie : kewpie
# yoghurt : yoghurt
# jarang : jarang
# ditemukan : temu
# sementara : sementara
# blueberry : blueberry
# bersih : bersih
# pengaturannya : atur
# terlihat : lihat
# menggugah : gugah
# there : there
# sturdy : sturdy
# buahan : buah
# yogurt : yogurt
# temukan : temu
# ditempat : tempat
# almond : almond
# slices : slices
# tanpa : tanpa
# dinaikan : naik
# duh : duh
# dibilang : bilang
# blueberrynya : blueberrynya
# sekalipun : sekalipun
# dibuat : buat
# pukul : pukul
# lewat : lewat
# mevvah : mevvah
# reasonable : reasonable
# kismisnya : kismis
# lembab : lembab
# karet : karet
# utamakan : utama
# mari : mari
# daerah : daerah
# kelapa : kelapa
# gading : gading
# banjir : banjir
# nge : nge
# dropship : dropship
# kebun : kebun
# mereka : mereka
# mulai : mulai
# akun : akun
# dropshipper : dropshipper
# usaha : usaha
# ah : ah
# huwehehe : huwehehe
# kejunya : keju
# macem : macem
# going : going
# be : be
# last : last
# cakeep : cakeep
# deeh : deeh
# soal : soal
# ragukan : ragu
# selaluuuuu : selaluuuuu
# enaakk : enaakk
# ng : ng
# difoto : foto
# teruji : uji
# berubah : ubah
# nano : nano
# terfavorit : favorit
# mantaab : mantaab
# segerrrrr : segerrrrr
# wajib : wajib
# cobaiiiin : cobaiiiin
# taon : taon
# ngidamnya : ngidamnya
# kesampaian : sampai
# parah : parah
# seuugeeeeernya : seuugeeeeernya
# mng : mng
# mata : mata
# melek : melek
# nch : nch
# br : br
# rasain : rasain
# enaknya : enak
# gn : gn
# airnya : air
# layanannnya : layanannnya
# dagangannya : dagang
# sll : sll
# durianya : durianya
# dijual : jual
# insha : insha
# allah : allah
# grab : grab
# berasaaa : berasaaa
# aslinya : asli
# tidak apa-apa : tidak apa
# diisi : isi
# ka : ka
# enakkkkkks : enakkkkkks
# abang : abang
# mkshhh : mkshhh
# manfaat : manfaat
# barokah : barokah
# selaluuuuuu : selaluuuuuu
# bonusan : bonus
# masya : masya
# berikan : ikan
# usahanya : usaha
# lancarrrr : lancarrrr
# looh : looh
# insyaallah : insyaallah
# barakallah : barakallah
# tanggung : tanggung
# jawab : jawab
# rubah : rubah
# yaaaa : yaaaa
# detail : detail
# tertera : tera
# muslim : muslim
# penyelamat : selamat
# mual : mual
# muntah : muntah
# heran : heran
# busyet : busyet
# asiin : asiin
# rasnya : ras
# ngangenin : ngangenin
# hauss : hauss
# pembuka : buka
# warung : warung
# coyyyyyyy : coyyyyyyy
# euy : euy
# asinnya : asin
# cupnya : cup
# duriannya : durian
# saya kira : saya kira
# boleh : boleh
# laahhh : laahhh
# penuh : penuh
# rapiterima : rapiterima
# sayurbox : sayurbox
# layanannya : layan
# dimasukkan : masuk
# terkirim : kirim
# bersama : sama
# mudah : mudah
# berhasil : hasil
# refund : refund
# nanasnya : nanas
# diinfoin : diinfoin
# cara : cara
# selesai : selesai
# otomatis : otomatis
# segarrrr : segarrrr
# cuttingnya : cuttingnya
# biji : biji
# santap : santap
# tanah : tanah
# dilidah : lidah
# maknyusss : maknyusss
# mgk : mgk
# ketinggalan : tinggal
# bagaimana : bagaimana
# habisin : habisin
# kehitung : hitung
# enaaaakkkk : enaaaakkkk
# bingitzzzzz : bingitzzzzz
# puluh : puluh
# member : member
# alias : alias
# kelupaan : lupa
# saking : saking
# ingat : ingat
# putih : putih
# segeer : segeer
# buru : buru
# dimasukan : masuk
# kulkas : kulkas
# khilaf : khilaf
# makasihhhhh : makasihhhhh
# tuanks : tuanks
# catatan : catat
# biarkan : biar
# tangan : tangan
# sedeep : sedeep
# mangganya : mangga
# berair : air
# sukakkk : sukakkk
# soon : soon
# pokokya : pokokya
# via : via
# wa : wa
# bae : bae
# transaksi : transaksi
# mnggany : mnggany
# bkl : bkl
# ngidam : ngidam
# mesti : mesti
# diikat : ikat
# erat : erat
# termina : mina
# terasinya : terasi
# stock : stock
# baraang : baraang
# cepeett : cepeett
# bangeett : bangeett
# jooss : jooss
# bonuus : bonuus
# mendarat : darat
# lebihnya : lebih
# iklan : iklan
# mantabbbb : mantabbbb
# duren : duren
# dalem : dalem
# uenakkk : uenakkk
# langgan : langgan
# joss : joss
# bollen : bollen
# kerenn : kerenn
# menikmati : nikmat
# bolen : bolen
# sejak : sejak
# penyok : penyok
# pia : pia
# keinginan : ingin
# thankyouu : thankyouu
# masukkan : masuk
# dihancurkannya : hancur
# seragam : seragam
# homogen : homogen
# piece : piece
# bolu : bolu
# wow : wow
# serapih : serapih
# bangettsss : bangettsss
# jadul : jadul
# sekedar : dar
# menambah : tambah
# sampah : sampah
# kuenya : kue
# dinotice : dinotice
# diharapkan : harap
# ijonya : ijonya
# jelas : jelas
# pesananku : pesan
# greeting : greeting
# luvvv : luvvv
# paraaah : paraaah
# okeee : okeee
# endul : endul
# maluin : maluin
# tetangga : tetangga
# kaaaa : kaaaa
# hancurr : hancurr
# manntaabbb : manntaabbb
# sebenernya : sebenernya
# enggak : enggak
# bakalan : bakal
# me : me
# harumnya : harum
# menggoda : goda
# two : two
# coklatnya : coklat
# adminnya : adminnya
# konfirmasi : konfirmasi
# greentea : greentea
# grenteacheese : grenteacheese
# meleleh : leleh
# inii : ini
# bahayaa : bahayaa
# semalam : malam
# talasnya : talas
# lezat : lezat
# kloter : kloter
# keberapa : berapa
# syukaa : syukaa
# enaaakkkkk : enaaakkkkk
# respin : respin
# diterima dengan : terima dengan
# manusnya : manusnya
# livana : livana
# outlet : outlet
# memudahkan : mudah
# keren : keren
# jamin : jamin
# shopping : shopping
# istimevvah : istimevvah
# notice : notice
# estimasi : estimasi
# dibahas : bahas
# daeebaakk : daeebaakk
# juaraaa : juaraaa
# ahhh : ahhh
# sukaaa : sukaaa
# menggemaskan : gemas
# berdua : dua
# bangeeet : bangeeet
# ongol : ongol
# ongolnya : ongolnya
# kenyal : kenyal
# gemblongnya : gemblong
# gulanya : gula
# keringnya : kering
# ketannya : ketan
# gacor : gacor
# kata : kata
# sebaiknya : baik
# gula : gula
# merahnya : merah
# rebutan : rebut
# brownisnya : brownisnya
# enaaakkkk : enaaakkkk
# primarasa : primarasa
# lawanlah : lawan
# terguncang : guncang
# expire : expire
# pendek : pendek
# jangka : jangka
# waktunya : waktu
# mix : mix
# akutuh : akutuh
# brownis : brownis
# berani : berani
# siiip : siiip
# slowwwwww : slowwwwww
# bakpianya : bakpia
# pengirimaan : pengirimaan
# jogja : jogja
# bekasi : bekas
# masukin : masukin
# wueeenakkk : wueeenakkk
# tenannnnn : tenannnnn
# mulusss : mulusss
# kendala : kendala
# ap : ap
# dm : dm
# update : update
# babang : babang
# bandung : bandung
# cabang : cabang
# selles : selles
# mengkomunikasikan : komunikasi
# mei : mei
# krmnya : krmnya
# bangetttttttt : bangetttttttt
# gerak : gerak
# dijemput : jemput
# services : services
# bali : bal
# sebulan : bulan
# lumer : lumer
# mulut : mulut
# legongnnya : legongnnya
# peak : peak
# season : season
# level : level
# bervariasi : variasi
# dipercaya : percaya
# legitnya : legit
# terluv : terluv
# kelapanya : kelapa
# kacau : kacau
# medok : medok
# gemblong : gemblong
# delish : delish
# ikut : ikut
# tertekan : tekan
# utamanya : utama
# vanilla : vanilla
# soesnya : soesnya
# hmmm : hmmm
# awal : awal
# pikir : pikir
# mirip : mirip
# beard : beard
# papa : papa
# sus : sus
# my : my
# liking : liking
# light : light
# tooopppp : tooopppp
# rum : rum
# matcha : matcha
# krim : krim
# aroma : aroma
# jasmine : jasmine
# choco : choco
# gosend : gosend
# wismannya : wismannya
# pinggir : pinggir
# packingngya : packingngya
# gmn : gmn
# overprice : overprice
# pinggiran : pinggir
# sekalian : sekali
# monica : monica
# alfamart : alfamart
# nempel : nempel
# tips : tips
# ngasal : ngasal
# menemukan : temu
# takdir : takdir
# baca : baca
# berminyak : minyak
# maafin : maafin
# menyelamatkan : selamat
# kekecewaan : kecewa
# rasakan : rasa
# he : he
# hee : hee
# aneh : aneh
# paraaahhhh : paraaahhhh
# sebelah : belah
# penasaran : penasaran
# mooncake : mooncake
# harganya : harga
# compare : compare
# kalah : kalah
# bestsellernya : bestsellernya
# pandan : pandan
# kc : kc
# merah : merah
# doyan : doyan
# kpn : kpn
# ingin : ingin
# umumnya : umum
# penyet : penyet
# rekomended : rekomended
# bangeet : bangeet
# kuenyaa : kuenyaa
# bungkusan : bungkus
# jawa : jawa
# bingiiitsss : bingiiitsss
# enaakkk : enaakkk
# stabil : stabil
# titik : titik
# debat : debat
# bengkoang : bengkoang
# puasss : puasss
# ini sudah : ini sudah
# maknyooossssse : maknyooossssse
# kerennnnn : kerennnnn
# tengah : tengah
# barusan : barusan
# masuknya : masuk
# sehari : hari
# depok : depok
# mochi : mochi
# berantakan : beranta
# moachi : moachi
# gemini : gemini
# abisss : abisss
# tanggerang : tanggerang
# oreo : oreo
# kebalik : balik
# orderjumat : orderjumat
# pie : pie
# susu : susu
# produksi : produksi
# mantaaapp : mantaaapp
# denpasar : denpasar
# terbaru : baru
# meskipun : meski
# enaaaak : enaaaak
# eunakkk : eunakkk
# gilakkk : gilakkk
# babinya : babi
# temennya : temennya
# hioko : hioko
# lapchong : lapchong
# berkata : kata
# yah saya : yah saya
# mo : mo
# menghabiskan : habis
# pulau : pulau
# benerrr : benerrr
# boongg : boongg
# mao : mao
# buatnya : buat
# bolunya : bolu
# truss : truss
# moistt : moistt
# wenakkk : wenakkk
# recomen : recomen
# filling : filling
# kt : kt
# bolgul : bolgul
# ngopi : ngopi
# mantaaa : mantaaa
# aaappp : aaappp
# dichat : dichat
# antri : antri
# mendekati : dekat
# pengemasannya : emas
# siapa : siapa
# amat : amat
# fragile : fragile
# iya : iya
# bekas : bekas
# ketumpuk : tumpuk
# kerabat : kerabat
# gila : gila
# suruh : suruh
# menelan : tel
# sebenarnya : benar
# banana : banana
# rollnya : rollnya
# kemana : mana
# nihh : nihh
# terkocok : kocok
# gepeng : gepeng
# merubah : rubah
# kecuali : kecuali
# khas : khas
# caikue : caikue
# pontianak : pontianak
# bawa : bawa
# keliatannya : liat
# sempurna : sempurna
# beh : beh
# mantulllll : mantulllll
# hahahahahaha : hahahahahaha
# tulis : tulis
# edisi : edisi
# sama sekali : sama sekali
# ig : ig
# dibalas : balas
# gini : gin
# gemeshhh : gemeshhh
# bgtdpt : bgtdpt
# paperbag : paperbag
# ma : ma
# kartuny : kartuny
# chewwy : chewwy
# small : small
# dsn : dsn
# cookiesnya : cookiesnya
# uenaakkk : uenaakkk
# lotus : lotus
# biscoff : biscoff
# team : team
# cookiesnyaa : cookiesnyaa
# sukaaaaa : sukaaaaa
# enaaaaaaaaaaaaaaaak : enaaaaaaaaaaaaaaaak
# gedeee : gedeee
# ro : ro
# polll : polll
# enakkkkkk : enakkkkkk
# nastar : nastar
# wisman : wisman
# susunya : susu
# dikurangi : rang
# enakkkkkkkkkkkkkkkkkkkkkkkkkkk : enakkkkkkkkkkkkkkkkkkkkkkkkkkk
# yaass : yaass
# pienya : pienya
# pembungkusnya : bungkus
# bunch : bunch
# informative : informative
# kondisinya : kondisi
# amannnn : amannnn
# wajar : wajar
# buble : buble
# selanjutnya : lanjut
# dicantumkan : cantum
# kek : kek
# kepastian : pasti
# haha : haha
# pwrjo : pwrjo
# entaraja : entaraja
# telat : telat
# kurirnya : kurir
# oo : oo
# alhamdullah : alhamdullah
# mulus : mulus
# pacar : pacar
# checkout : checkout
# capat : capat
# kaka : kaka
# rapiaman : rapiaman
# daaaan : daaaan
# mantavvv : mantavvv
# bakpia : bakpia
# pancking : pancking
# bakpianyaa : bakpianyaa
# pax : pax
# diperhatiin : diperhatiin
# tanggalnya : tanggal
# cemilan : cemilan
# krucil : krucil
# yogya : yogya
# matabbzz : matabbzz
# cepaat : cepaat
# duit : duit
# kembalikan : kembali
# sisanya : sisa
# ekspetasi : ekspetasi
# dipengiriman : kirim
# spikoenya : spikoenya
# reguler : reguler
# terpercaya : percaya
# memakai : pakai
# spikoe : spikoe
# renyek : renyek
# ketekan : tekan
# repot : repot
# rabu : rabu
# kedatangan : datang
# bentuk : bentuk
# rasanyaaaa : rasanyaaaa
# sukakkkkk : sukakkkkk
# nastarnya : nastarnya
# bublewarpnya : bublewarpnya
# anterajasangat : anterajasangat
# ajar : ajar
# dilempar : lempar
# kedalam : dalam
# melewati : lewat
# pagar : pagar
# tinggi : tinggi
# pergi : pergi
# suami : suami
# bangeeettt : bangeeettt
# lembuutt : lembuutt
# bt : bt
# remuk : remuk
# mantaaabbb : mantaaabbb
# spec : spec
# kaaaaak : kaaaaak
# maahal : maahal
# kruncii : kruncii
# sebagian : bagi
# malang : malang
# lot : lot
# hokaido : hokaido
# aaaaaaa : aaaaaaa
# hambar : hambar
# ringan : ringan
# jaga : jaga
# pola : pola
# jadikan : jadi
# lapar : lapar
# baguss : baguss
# siii : siii
# termasuk : masuk
# puaaass : puaaass
# kaget : kaget
# makasii : makasii
# susulan : susul
# parsel : parsel
# terkejar : kejar
# roti : roti
# main : main
# lempar : lempar
# wysmannya : wysmannya
# nanas : nanas
# mank : mank
# paduan : padu
# bocah : bocah
# kriuk : kriuk
# jaya : jaya
# uenaaakk : uenaaakk
# menyusul : susul
# maknyuss : maknyuss
# accurate : accurate
# as : as
# aaa : aaa
# cookie : cookie
# lekker : lekker
# toping : toping
# rock : rock
# salt : salt
# uenake : uenake
# poll : poll
# edannnnnn : edannnnnn
# bgtttt : bgtttt
# apel : apel
# lahap : lahap
# challa : challa
# setiap : tiap
# sinu : sinu
# thaaanks : thaaanks
# pastry : pastry
# wanginya : wangi
# wangiiinyaa : wangiiinyaa
# menusukk : menusukk
# dihidung : hidung
# suksessss : suksessss
# grandpas : grandpas
# jakbar : jakbar
# asli sesuai : asli sesuai
# aplikasi : aplikasi
# pengirimnya : kirim
# mangkok : mangkok
# wkwk : wkwk
# Terima kasih ya tuhan : terima kasih ya tuhan
# damage : damage
# photocard : photocard
# bangtan : bangtan
# nilai : nilai
# bermanfaat : manfaat
# umi : umi
# jember : jember
# event : event
# bts : bts
# pokoo : pokoo
# membuat : buat
# adalah : adalah
# alur : alur
# tokocabang : tokocabang
# membatalkan : batal
# penjelasan : jelas
# notifikasi : notifikasi
# tokopedianya : tokopedianya
# harap : harap
# kasus : kasus
# batal : batal
# alamatnya : alamat
# dibatalkan : batal
# ribet : ribet
# adanya : ada
# yeay : yeay
# siip : siip
# rekommended : rekommended
# renyahpackingnya : renyahpackingnya
# tanda : tanda
# stiker : stiker
# hingga : hingga
# membutuhkan : butuh
# datenya : datenya
# lamaan : lama
# roll : roll
# chesse : chesse
# mampir : mampir
# ks : ks
# ngerti : ngerti
# tidak mengerti : tidak erti
# bgttt : bgttt
# teruuussss : teruuussss
# too : too
# sweet : sweet
# higienis : higienis
# nyambung : nyambung
# endorphins : endorphins
# garam : garam
# enaaaaaaak : enaaaaaaak
# bingiiiit : bingiiiit
# mantepp : mantepp
# duanya : dua
# sincia : sincia
# lengket : lengket
# sllu : sllu
# pengirimman : pengirimman
# gunakan : guna
# terbelah : belah
# keduanya : dua
# higienisnya : higienis
# seandainya : anda
# keadaannya : ada
# kemungkinannya : mungkin
# tersebut : sebut
# terkontaminasi : kontaminasi
# sesuatu : sesuatu
# ikuti : ikut
# anda : anda
# jangankan : jangan
# niat : niat
# dibaca : baca
# feb : feb
# modus : modus
# seolah : olah
# kalian : kalian
# perduli : duli
# calon : calon
# jawaban : jawab
# itikad : itikad
# merasa : rasa
# diuntungkan : untung
# dijadikan : jadi
# pembenaran : benar
# transaksinya : transaksi
# ribu : ribu
# uang : uang
# ngomong : ngomong
# rapiii : rapiii
# enaaaakkkkk : enaaaakkkkk
# pk : pk
# recommaded : recommaded
# soft : soft
# muraaahh : muraaahh
# bingiiittsss : bingiiittsss
# kaki : kaki
# lima : lima
# bubuk : bubuk
# hahaha : hahaha
# originalnya : originalnya
# almondnya : almondnya
# gosendnya : gosendnya
# nyicipin : nyicipin
# tidak pernah : tidak pernah
# kd : kd
# kabel : kabel
# ties : ties
# jempolsss : jempolsss
# sukakk : sukakk
# diantarkan : antar
# mantaaappss : mantaaappss
# antara : antara
# dibatasi : batas
# naik : naik
# tidak ada : tidak ada
# biskuit : biskuit
# muluusss : muluusss
# beneerran : beneerran
# katanyaa : katanyaa
# approved : approved
# gilaaa : gilaaa
# kasi : kasi
# kukasi : kas
# aq : aq
# khawatir : khawatir
# marah : marah
# alhasil : alhasil
# looohh : looohh
# hebaaatt : hebaaatt
# hebaaat : hebaaat
# serbis : serbis
# juwaraaakkk : juwaraaakkk
# makasiiihhhh : makasiiihhhh
# oh : oh
# milk : milk
# mahaaall : mahaaall
# juwaraakk : juwaraakk
# juwaraak : juwaraak
# sangat bagus : sangat bagus
# uenaaknya : uenaaknya
# interaktif : interaktif
# citarasa : citarasa
# nutella : nutella
# melting : melting
# if : if
# canele : canele
# ive : ive
# had : had
# safe : safe
# terlebih : lebih
# masa : masa
# pandemi : pandemi
# telo : telo
# knot : knot
# anything : anything
# bahkan : bahkan
# lem : lem
# alamat : alamat
# caranya : cara
# lover : lover
# keramahan : ramah
# dekorasi : dekorasi
# kuex : kuex
# berkati : berkat
# membawa : bawa
# kebahagiaan : bahagia
# memesan : mes
# komposisi : komposisi
# jiwa : jiwa
# ngorder : ngorder
# papua : papua
# donggz : donggz
# manteep : manteep
# hiasannya : hias
# mewah : mewah
# high : high
# setiap orang : tiap orang
# momoiro : momoiro
# chizu : chizu
# kk : kk
# dipenuhi : penuh
# enakan : enak
# nyangka : nyangka
# separah : parah
# kekeuh : kekeuh
# jiggly : jiggly
# fluppy : fluppy
# moiss : moiss
# caramel : caramel
# butter : butter
# dipickup : dipickup
# pickup : pickup
# pagian : pagi
# cust : cust
# kemalaman : malam
# helpfull : helpfull
# youu : youu
# jadwal : jadwal
# bithday : bithday
# embaknya : embak
# bertanggung : tanggung
# ngerepotin : ngerepotin
# layani : layan
# aktif : aktif
# ps : ps
# permen : permen
# dcabuttuh : dcabuttuh
# kreme : kreme
# donutnya : donutnya
# sukaaakkk : sukaaakkk
# cemilin : cemilin
# donat : donat
# donatnya : donat
# wowww : wowww
# informasi : informasi
# berat : berat
# mantaabbbb : mantaabbbb
# makanya : makanya
# thai : thai
# mmg : mmg
# strawberry : strawberry
# cheesecake : cheesecake
# better : better
# regal : regal
# fsnya : fsnya
# luber : luber
# mungil : mungil
# bday : bday
# outdoor : outdoor
# cakepppppp : cakepppppp
# expresss : expresss
# mantabbb : mantabbb
# gemesh : gemesh
# youuu : youuu
# mantabbbbbbbb : mantabbbbbbbb
# grabbike : grabbike
# enyaaak : enyaaak
# makasiiih : makasiiih
# yaah : yaah
# omg : omg
# baguuusss : baguuusss
# tega : tega
# motongnya : motongnya
# anakku : anak
# seneeeng : seneeeng
# adiknya : adik
# thankyouuuuuuuu : thankyouuuuuuuu
# sangaatt : sangaatt
# rapiihh : rapiihh
# terjangkauuuu : terjangkauuuu
# cari : cari
# segera : segera
# prod : prod
# tx : tx
# egg : egg
# lemonnya : lemon
# second : second
# basque : basque
# ennakk : ennakk
# cheesy : cheesy
# kombinasi : kombinasi
# dibakar : bakar
# memperkaya : kaya
# pencinta : cinta
# andalan : andal
# makannya : makan
# cheesecakenya : cheesecakenya
# jumlah : jumlah
# pengantarannya : antar
# ergu : ergu
# pokok : pokok
# kereen : kereen
# baguuus : baguuus
# mantaaaap : mantaaaap
# salam : salam
# kurnya : kur
# wooow : wooow
# maaantaaaab : maaantaaaab
# tart : tart
# senantiasa : senantiasa
# ...
# asiiin : asiiin
# setahu : tahu
# lapak : lapak
# sk : sk
# bulu : bulu
# terimskasiih : terimskasiih
# terpaksa : paksa
# dibuang : buang
# reccomended : reccomended
# pesing : pesing
# mangut : mangut
# pari : pari
# sp : sp
# oishii : oishii
# norinya : norinya
# saucenya : saucenya
# aaamiin : aaamiin
# simple : simple
# kedepannya : depan
# asikkk : asikkk
# restok : restok
# seeeepppp : seeeepppp
# michin : michin
# tujuh : tujuh
# seaweed : seaweed
# yahud : yahud
# bin : bin
# success : success
# ups : ups
# krupuknya : krupuknya
# ditengahnya : tengah
# bgks : bgks
# kerupuknya : kerupuk
# masyaallah : masyaallah
# luarbiasa : luarbiasa
# alila : alila
# transfer : transfer
# kerupuk : kerupuk
# palembang : palembang
# tenggiri : tenggiri
# nja : nja
# rating : rating
# bertuliskan : tulis
# digambar : gambar
# secarik : carik
# pulpen : pulpen
# bisanya : bisa
# ala : ala
# muhasabah : muhasabah
# diri : diri
# perilaku : perilaku
# mgg : mgg
# nikah : nikah
# keepthe : keepthe
# ludess : ludess
# pengirimqn : pengirimqn
# serpon : serpon
# bantet : bantet
# sidah : sidah
# angin : angin
# banyaaak : banyaaak
# terbanting : banting
# silam : silam
# pantas : pantas
# kadaluarsanya : kadaluarsanya
# berbau : bau
# berdasarkan : dasar
# value : value
# makaroninya : makaroni
# remah : remah
# ditolerir : tolerir
# semangat : semangat
# emping : emping
# masalahlah : masalah
# pecinta : cinta
# lawan : lawan
# dilapis : lap
# punn : punn
# muaskan : muas
# getas : getas
# kemplangnya : kemplang
# sampainya : sampai
# tengiri : tengiri
# brrminyak : brrminyak
# mantapppppp : mantapppppp
# sambil : sambil
# nonton : nonton
# pembawa : bawa
# mengevaluasi : evaluasi
# model : model
# muraahh : muraahh
# mantuuuulllllll : mantuuuulllllll
# endullll : endullll
# lemak : lemak
# nian : nian
# kekurangan : kurang
# lahir : lahir
# bathin : bathin
# digorengnya : goreng
# gampil : gampil
# rambaknya : rambak
# mekar : mekar
# renyaaaahhhh : renyaaaahhhh
# rapihh : rapihh
# enaknyaaa : enaknyaaa
# samcannya : samcannya
# dipack : dipack
# deliki : delik
# komunikasinya : komunikasi
# lm : lm
# bismillahirrahmanirrahiim : bismillahirrahmanirrahiim
# lindungi : lindung
# tindakan : tindak
# keputusan : putus
# anugerahi : anugerah
# keselamatan : selamat
# dunia : dunia
# akhirat : akhirat
# mutu : mutu
# shipping : shipping
# makasiii : makasiii
# nourish : nourish
# coconat : coconat
# flakes : flakes
# baguuuus : baguuuus
# tahunya : tahu
# megkilat : megkilat
# ko : ko
# keripikan : keripikan
# almh : almh
# zuhdi : zuhdi
# size : size
# diperbesar : besar
# disesuaikan : sesuai
# endeusss : endeusss
# pisan : pis
# karaknya : karaknya
# solo : solo
# mengembang : kembang
# dijemur : jemur
# karak : karak
# nan : nan
# kiamboy : kiamboy
# rentak : rentak
# terusss : terusss
# cepettt : cepettt
# wrab : wrab
# terbaikkk : terbaikkk
# aje : aje
# gileeee : gileeee
# ngemil : ngemil
# meong : meong
# biasaaa : biasaaa
# dicek : cek
# difotoin : difotoin
# sesudah : sudah
# bolak : bolak
# halo : halo
# cemilannya : cemilannya
# digunakan : guna
# apakah : apakah
# qo : qo
# mie : mie
# berminyaaak : berminyaaak
# over : over
# dee : dee
# kesakian : saki
# pesennn : pesennn
# muantabbb : muantabbb
# kremesannya : kremesannya
# hahahha : hahahha
# diadu : adu
# kemplang : kemplang
# trrlalu : trrlalu
# raapih : raapih
# imlek : imlek
# tamu : tamu
# picture : picture
# kematangan : matang
# siippdehh : siippdehh
# gendut : gendut
# menul : menul
# buanget : buanget
# sudahlah : sudah
# rikues : rikues
# ampir : ampir
# set : set
# tkp : tkp
# kelewat : lewat
# takjil : takjil
# canelle : canelle
# alasannya : alas
# menginformasikan : informasi
# keterlambatan : lambat
# snacknya : snacknya
# biscuitnya : biscuitnya
# ituh : ituh
# meiji : meiji
# crackers : crackers
# oat : oat
# cracker : cracker
# off : off
# market : market
# biskuitnya : biskuit
# lady : lady
# finger : finger
# rawan : rawan
# pesanannya : pesan
# disayangkan : sayang
# hancurnya : hancur
# ramai : ramai
# terimanya : terima
# hayooo : hayooo
# seal : seal
# by : by
# higienitasnya : higienitasnya
# ojol : ojol
# khannnn : khannnn
# gabin : gabin
# tapenyaaa : tapenyaaa
# dibungkus : bungkus
# terpisah : pisah
# tape : tape
# dipanggang : panggang
# gabunnya : gabunnya
# pelaksanaan : laksana
# diulangi : ulang
# dipaket : paket
# ttap : ttap
# janlupasholwat : janlupasholwat
# sesuailah : sesuai
# way : way
# ditambahkan : tambah
# kusuka : suka
# wfh : wfh
# reponnya : reponnya
# standart : standart
# dpaksa : dpaksa
# digencet : gencet
# boxnya : boxnya
# pengok : kok
# boromonnya : boromonnya
# thankyouuu : thankyouuu
# disukai : suka
# nostalgia : nostalgia
# puasssss : puasssss
# oklah : oklah
# kekurangannya : kurang
# dikemut : kemut
# kakkk : kakkk
# contohnya : contoh
# sprinkle : sprinkle
# sprinkles : sprinkles
# bulannya : bulan
# mannnnttttaaaaaaaappppppp : mannnnttttaaaaaaaappppppp
# yups : yups
# ane : ane
# yeaayyyy : yeaayyyy
# akibat : akibat
# disimpan : simpan
# utuhh : utuhh
# corniche : corniche
# marshmallow : marshmallow
# permennya : permen
# manisan : manis
# mantap asem : mantap asem
# lurang : lurang
# persis : persis
# jajanan : jajan
# diwarung : warung
# jahenya : jahe
# bulat : bulat
# ulir : ulir
# dekor : dekor
# suvenir : suvenir
# tooooooooop : tooooooooop
# bales : bales
# expedisi : expedisi
# mengulang : ulang
# maknyussss : maknyussss
# terpajang : pajang
# mantttttuuuuuuuuul : mantttttuuuuuuuuul
# juragann : juragann
# plong : plong
# warmderland : warmderland
# restock : restock
# cuss : cuss
# kalap : kalap
# tersayang : sayang
# bantuannya : bantu
# berbelanja : belanja
# manuka : manuka
# beri : beri
# pkokna : pkokna
# yuaa : yuaa
# nich : nich
# pemberitahuannya : pemberitahuannya
# diandalkan : andal
# mannnttaabb : mannnttaabb
# toopp : toopp
# cup : cup
# plain : plain
# jempoolll : jempoolll
# dicancel : dicancel
# bossz : bossz
# berulang : ulang
# kalinyaa : kalinyaa
# setahun : tahun
# baarakallahu : baarakallahu
# fiik : fiik
# bismillahi : bismillah
# walhamdulillah : walhamdulillah
# jelly : jelly
# trjangkau : trjangkau
# pnjualnya : pnjualnya
# kerusakan : rusa
# degan : degan
# cepettttt : cepettttt
# kemasann : kemasann
# jugaaa : jugaaa
# superrr : superrr
# rapii : rapi
# cepettttttt : cepettttttt
# rainbow : rainbow
# pengawet : awet
# sumatera : sumatera
# sejauha : sejauha
# minus : minus
# balut : balut
# karton : karton
# buar : buar
# pdng : pdng
# langgann : langgann
# cincau : cincau
# hijaunya : hijau
# grand : grand
# lucky : lucky
# caritau : caritau
# healthy : healthy
# well : well
# copat : copat
# chatime : chatime
# bubblenya : bubblenya
# puaas : puaas
# thankssss : thankssss
# inaco : inaco
# mantaaaappp : mantaaaappp
# cepaatt : cepaatt
# permasalahan : masalah
# pearl : pearl
# menginap : inap
# enaaaaakkk : enaaaaakkk
# mantaaab : mantaaab
# timbanganya : timbanganya
# bosqu : bosqu
# halu : halu
# enaakkkkk : enaakkkkk
# ketetangga : tetangga
# penambah : tambah
# omen : omen
# usahain : usahain
# kriu : kriu
# rap : rap
# ngunyah : ngunyah
# ueenaaakk : ueenaaakk
# udara : udara
# pisang : pisang
# memes : mes
# gagal : gagal
# kentang : kentang
# rendang : rendang
# film : film
# tse : tse
# manstabb : manstabb
# insyaallahu : insyaallahu
# pengen : ken
# stik : stik
# patahan : patah
# gabus : gabus
# weh : weh
# ususnya : usus
# gaeess : gaeess
# manisss : manisss
# utama : utama
# krispi : krispi
# makasiih : makasiih
# luck : luck
# pembungkusanya : pembungkusanya
# dipertahanin : dipertahanin
# pebgiriman : pebgiriman
# lidinya : lidi
# ngetik : ngetik
# huruf : huruf
# suukaaaa : suukaaaa
# sumpia : sumpia
# puazzz : puazzz
# horror : horror
# murahan : murah
# harian : hari
# padang : padang
# baladonya : baladonya
# serley : serley
# lado : lado
# shirley : shirley
# mikirin : mikirin
# mehong : mehong
# sinjai : sinjai
# maaanstaabb : maaanstaabb
# gaaannn : gaaannn
# pancen : pancen
# tekan : tekan
# atiku : ati
# mantaaaabbbb : mantaaaabbbb
# kremes : kremes
# benerrrr : benerrrr
# matah : matah
# beuhhhh : beuhhhh
# king : king
# pengemasannn : pengemasannn
# cepett : cepett
# sekaranggg : sekaranggg
# sampeee : sampeee
# makasiiii : makasiiii
# kegurihan : gurih
# menggelitik : gelitik
# kudapan : kudap
# pelengkap : lengkap
# basrengnya : basrengnya
# maicih : maicih
# makasiihhh : makasiihhh
# renyahnya : renyah
# gemuk : gemuk
# nyemil : nyemil
# senangnya : senang
# pempek : pempek
# metro : metro
# cokoten : cokoten
# mendapatkan : dapat
# pabriknya : pabrik
# umum : umum
# mantapsss : mantapsss
# oookkkee : oookkkee
# makaroni : makaroni
# candy : candy
# mpeknya : mpeknya
# uenaaaakkk : uenaaaakkk
# tegal : tegal
# kasihhh : kasihhh
# sampaii : sampai
# ibi : ibi
# perdana : perdana
# piscok : piscok
# balitaku : balitaku
# infokan : info
# responny : responny
# keplang : plang
# chintacink : chintacink
# topedsicptreg : topedsicptreg
# msg : msg
# seasoning : seasoning
# dos : dos
# acur : acur
# demikian : demikian
# dipakein : dipakein
# biaya : biaya
# ueeenak : ueeenak
# bzmgettt : bzmgettt
# nagihin : nagihin
# ngett : ngett
# mantapzzz : mantapzzz
# satunya : satu
# rapipengiriman : rapipengiriman
# woow : woow
# mengganti : ganti
# peaan : peaan
# enaaaaakkkkk : enaaaaakkkkk
# kelain : lain
# hatiii : hatiii
# buktiin : buktiin
# ajeee : ajeee
# ne : ne
# favoritnya : favorit
# sabina : sabina
# anggota : anggota
# menggumpal : gumpal
# tercampur : campur
# jadwalnya : jadwal
# wenaak : wenaak
# siapkan : siap
# dari pada : dari pada
# dicari : cari
# yummiest : yummiest
# bund : bund
# puedass : puedass
# accept : accept
# pedess : pedess
# basreng : basreng
# zona : zona
# perang : perang
# adzan : adzan
# renyahh : renyahh
# saoai : saoai
# singkongku : singkong
# ach : ach
# overpowerrr : overpowerrr
# yumm : yumm
# rapimakanannya : rapimakanannya
# moikafood : moikafood
# seret : seret
# dikira : kira
# strong : strong
# amisnya : amis
# basrennya : basrennya
# bangetttttt : bangetttttt
# jajannya : jajan
# lazis : lazis
# gatotnya : gatot
# direndam : rendam
# dikukus : kukus
# tanks : tanks
# sellertokopedia : sellertokopedia
# sukes : sukes
# itemnya : item
# lidi : lidi
# serbu : serbu
# lebat : lebat
# sempetin : sempetin
# nganter : nganter
# mobil : mobil
# kebasahan : basah
# mobilnya : mobil
# gang : gang
# terharu : haru
# perjuangannya : juang
# jobs : jobs
# recomment : recomment
# kebuka : buka
# emi : emi
# beyok : beyok
# rda : rda
# rapuh : rapuh
# haus : haus
# ngecek : ngecek
# akurat : akurat
# mengurangi : kurang
# citra : citra
# unboxing : unboxing
# jualanku : jual
# memproses : proses
# silinder : silinder
# terdengar : dengar
# remahan : remah
# serampangan : serampang
# intinya : inti
# respons cepat : respons cepat
# nov : nov
# direkomendasikan : rekomendasi
# mengirimkan : kirim
# muda : muda
# janjimu : janji
# numpang : numpang
# lgagustus : lgagustus
# normal : normal
# obral : obral
# kejar : kejar
# modal : modal
# maunya : mau
# merekomendasikan : rekomendasi
# ekspedisinya : ekspedisi
# uenaaakkk : uenaaakkk
# bm : bm
# kuliah : kuliah
# thankyouuuu : thankyouuuu
# metenya : mete
# panggangnya : panggang
# vacum : vacum
# kendor : kendor
# rentah : rentah
# manyap : manyap
# sticker : sticker
# facum : facum
# belah : belah
# xgr : xgr
# okeeeee : okeeeee
# pict : pict
# begini : begini
# vacuum : vacuum
# berlabel : label
# stocknya : stocknya
# muanttafff : muanttafff
# ajwa : ajwa
# jazakallah : jazakallah
# khoir : khoir
# terhitsss : terhitsss
# almon : almon
# semisal : misal
# siiiiippppp : siiiiippppp
# pic : pic
# levelnya : level
# walo : walo
# diwrap : diwrap
# guys : guys
# medenya : mede
# pass : pass
# seeh : seeh
# uueeenaaak : uueeenaaak
# dikeluarkan : keluar
# kelasnya : kelas
# rupa : rupa
# luv : luv
# nut : nut
# eating : eating
# breakfast : breakfast
# usually : usually
# kesuksessan : kesuksessan
# amiiiiiiiiiin : amiiiiiiiiiin
# sinargriya : sinargriya
# com : com
# kacapatri : kacapatri
# kwacinya : kwacinya
# kuaci : kuaci
# okk : okk
# crispi : crispi
# expres : expres
# banyuwangi : banyuwangi
# inshaa : inshaa
# mak : mak
# nyussssss : nyussssss
# goooooooooood : goooooooooood
# sampaikan : sampai
# slicenya : slicenya
# banyakan : banyak
# binatang : binatang
# hidup : hidup
# desember : desember
# jijik : jijik
# ordernya : order
# ganjel : ganjel
# dilayani : layan
# just : just
# kenari : kenari
# koronya : koronya
# buku : buku
# panggang : panggang
# roasted : roasted
# rentan : rentan
# apabila : apabila
# terjadi : jadi
# dibeli : beli
# honest : honest
# bawahnya : bawah
# dikomplain : komplain
# mengulur : ulur
# ngulur : ngulur
# almonnya : almonnya
# ak : ak
# membuka : buka
# september : september
# membaui : bau
# menyeruak : seruak
# cicip : cicip
# {'enak': 'enak', 'kuacinya': 'kuaci', 'pengiriman': 'kirim', 'cepat': 'cepat', 'pengemasan': 'emas', 'bagus': 'bagus', 'sesuai': 'sesuai', 'pesanan': 'pesan', 'belum': 'belum', 'di': 'di', 'coba': 'coba', 'terima': 'terima', 'kasih': 'kasih', 'luar': 'luar', 'biasa': 'biasa', 'baik': 'baik', 'untuk': 'untuk', 'rasa': 'rasa', 'menurut': 'turut', 'saya': 'saya', 'lebih': 'lebih', 'dominan': 'dominan', 'ke': 'ke', 'asli': 'asli', 'atau': 'atau', 'mau': 'mau', 'varian': 'varian', 'apapun': 'apa', 'soalnya': 'soal', 'rasanya': 'rasa', 'kurang': 'kurang', 'dan': 'dan', 'sedikit': 'sedikit', 'asin': 'asin', 'juga': 'juga', 'yang': 'yang', 'agak': 'agak', 'terasa': 'asa', 'itu': 'itu', 'rumput': 'rumput', 'laut': 'laut', 'lain': 'lain', 'nya': 'nya', 'mendominasi': 'dominasi', 'sih': 'sih', 'terima kasih': 'terima kasih', 'minimal': 'minimal', 'sudah': 'sudah', 'beli': 'beli', 'kesekian': 'sekian', 'kali': 'kali', 'mantap': 'mantap', 'enaak': 'enaak', 'guriih': 'guriih', 'kacang': 'kacang', 'respons': 'respons', 'harga': 'harga', 'terjangkau': 'jangkau', 'mantappppp': 'mantappppp', 'recommended': 'recommended', 'empingnya': 'emping', 'enakkkkk': 'enakkkkk', 'mantapppp': 'mantapppp', 'puas': 'puas', 'gurih': 'gurih', 'banget': 'banget', 'nanti': 'nanti', 'pesan': 'pesan', 'lagi': 'lagi', 'kesukaan': 'suka', 'kondisi': 'kondisi', 'kurir': 'kurir', 'mdhan': 'mdhan', 'rekomendasi': 'rekomendasi', 'renyah': 'renyah', 'rapi': 'rapi', 'lanjut': 'lanjut', 'seller': 'seller', 'tokopedia': 'tokopedia', 'segar': 'segar', 'bermutu': 'mutu', 'tumben': 'tumben', 'dari': 'dari', 'biasanya': 'biasa', 'hehe': 'hehe', 'kepingin': 'kepingin', 'makan': 'makan', 'keripik': 'keripik', 'pedas': 'pedas', 'aaaa': 'aaaa', 'sangat': 'sangat', 'buat': 'buat', 'dijadiin': 'dijadiin', 'snack': 'snack', 'makasihh': 'makasihh', 'ini': 'ini', 'terus': 'terus', 'naujubillah': 'naujubillah', 'tapi': 'tapi', 'ketagihan': 'tagih', 'walaupun': 'walaupun', 'mencret': 'mencret', 'kapok': 'kapok', 'teman': 'teman', 'sok': 'sok', 'sokan': 'sok', 'mencoba': 'coba', 'sampai': 'sampai', 'semua': 'semua', 'lengkap': 'lengkap', 'langganan': 'langgan', 'sejati': 'sejati', 'sukses': 'sukses', 'riki': 'riki', 'terjamin': 'jamin', 'pedasnya': 'pedas', 'gurihnya': 'gurih', 'pas': 'pas', 'cuma': 'cuma', 'tidak': 'tidak', 'berasa': 'asa', 'singkong': 'singkong', 'saran': 'saran', 'saja': 'saja', 'kalau': 'kalau', 'pembelian': 'beli', 'bungkus': 'bungkus', 'ada': 'ada', 'bonus': 'bonus', 'biar': 'biar', 'makin': 'makin', 'lariss': 'lariss', 'selalu': 'selalu', 'panas': 'panas', 'perut': 'perut', 'ge': 'ge', 'pengirimannya': 'kirim', 'aman': 'aman', 'baso': 'baso', 'acinya': 'aci', 'serius': 'serius', 'teksturnya': 'tekstur', 'kaca': 'kaca', 'khad': 'khad', 'garut': 'garut', 'isian': 'isi', 'ayamnya': 'ayam', 'barang': 'barang', 'benerannagih': 'benerannagih', 'kuah': 'kuah', 'pokoknya': 'pokok', 'manteppppp': 'manteppppp', 'mantapp': 'mantapp', 'kualitass': 'kualitass', 'lumayan': 'lumayan', 'cepatt': 'cepatt', 'terimakasii': 'terimakasii', 'toko': 'toko', 'nyaaaa': 'nyaaaa', 'dalam': 'dalam', 'keadaan': 'ada', 'pilus': 'pilus', 'cikur': 'cikur', 'alot': 'alot', 'lihat': 'lihat', 'lama': 'lama', 'paket': 'paket', 'diberi': 'beri', 'pcs': 'pcs', 'aci': 'aci', 'isi': 'isi', 'kecil': 'kecil', 'porsi': 'porsi', 'banyak': 'banyak', 'baru': 'baru', 'kemarin': 'kemarin', 'hari': 'hari', 'produk': 'produk', 'dengan': 'dengan', 'selamat': 'selamat', 'rusak': 'rusak', 'premium': 'premium', 'alhamdulillah': 'alhamdulillah', 'habis': 'habis', 'bisa': 'bisa', 'berhenti': 'henti', 'ginian': 'ginian', 'terbuka': 'buka', 'kemasannya': 'kemas', 'untung': 'untung', 'masih': 'masih', 'pelit': 'pelit', 'bumbunya': 'bumbu', 'belanja': 'belanja', 'disini': 'sini', 'kangen': 'kangen', 'terbayarkan': 'bayar', 'pagi': 'pagi', 'sekali': 'sekali', 'dikirim': 'kirim', 'malam': 'malam', 'patut': 'patut', 'dapat': 'dapat', 'bintang': 'bintang', 'telurnya': 'telur', 'garing': 'garing', 'bubble': 'bubble', 'pembungkus': ...
# ------------------------
# Pandas Apply:   0%|          | 0/4060 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df
# Out:
#                                                  Review  Rating  \
# 10                                        enak kuacinya       5
# 12    pengiriman cepat packing bagus sesuai pesanan ...       5
# 13    pengemasan luar biasa baik untuk rasa menurut ...       4
# 15                                      terimakasih min       5
# 16                   udah order untuk kesekian kali jos       5
# ...                                                 ...     ...
# 5421  seller sangat responsif rasa belum dicoba kare...       5
# 5422                           imut banget packing aman       5
# 5423                        good product trusted seller       5
# 5424                                  sudah beli yg ke        5
# 5425                                    byk campurannya       4
#
#                                            tokenization  \
# 10                                     [enak, kuacinya]
# 12    [pengiriman, cepat, packing, bagus, sesuai, pe...
# 13    [pengemasan, luar, biasa, baik, untuk, rasa, m...
# 15                                   [terimakasih, min]
# 16            [udah, order, untuk, kesekian, kali, jos]
# ...                                                 ...
# 5421  [seller, sangat, responsif, rasa, belum, dicob...
# 5422                      [imut, banget, packing, aman]
# 5423                   [good, product, trusted, seller]
# 5424                              [sudah, beli, yg, ke]
# 5425                                 [byk, campurannya]
#
#                                       Review_Normalized  \
# 10                                     [enak, kuacinya]
# 12    [pengiriman, cepat, pengemasan, bagus, sesuai,...
# 13    [pengemasan, luar, biasa, baik, untuk, rasa, m...
# 15                              [terima kasih, minimal]
# 16         [sudah, beli, untuk, kesekian, kali, mantap]
# ...                                                 ...
# 5421  [seller, sangat, responsif, rasa, belum, dicob...
# 5422                   [imut, banget, pengemasan, aman]
# 5423                  [good, produk, dipercaya, seller]
# 5424                            [sudah, beli, yang, ke]
# 5425                              [banyak, campurannya]
#
#                                          df_token_stemm
# 10                                        [enak, kuaci]
# 12    [kirim, cepat, emas, bagus, sesuai, pesan, bel...
# 13    [emas, luar, biasa, baik, untuk, rasa, turut, ...
# 15                              [terima kasih, minimal]
# 16           [sudah, beli, untuk, sekian, kali, mantap]
# ...                                                 ...
# 5421  [seller, sangat, responsif, rasa, belum, coba,...
# 5422                         [imut, banget, emas, aman]
# 5423                    [good, produk, percaya, seller]
# 5424                            [sudah, beli, yang, ke]
# 5425                                   [banyak, campur]
#
# [4060 rows x 5 columns]

# %%
#removing stopwords
from nltk.corpus import stopwords
nltk.download('stopwords')
def stopword(sentence):
    text = [words for words in sentence if words not in set(stopwords.words('indonesian'))]
    text = ' '.join(text)
    return text

df['Review_clean'] = df['df_token_stemm'].apply(stopword)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
df
# Out:
#                                                  Review  Rating  \
# 10                                        enak kuacinya       5
# 12    pengiriman cepat packing bagus sesuai pesanan ...       5
# 13    pengemasan luar biasa baik untuk rasa menurut ...       4
# 15                                      terimakasih min       5
# 16                   udah order untuk kesekian kali jos       5
# ...                                                 ...     ...
# 5421  seller sangat responsif rasa belum dicoba kare...       5
# 5422                           imut banget packing aman       5
# 5423                        good product trusted seller       5
# 5424                                  sudah beli yg ke        5
# 5425                                    byk campurannya       4
#
#                                            tokenization  \
# 10                                     [enak, kuacinya]
# 12    [pengiriman, cepat, packing, bagus, sesuai, pe...
# 13    [pengemasan, luar, biasa, baik, untuk, rasa, m...
# 15                                   [terimakasih, min]
# 16            [udah, order, untuk, kesekian, kali, jos]
# ...                                                 ...
# 5421  [seller, sangat, responsif, rasa, belum, dicob...
# 5422                      [imut, banget, packing, aman]
# 5423                   [good, product, trusted, seller]
# 5424                              [sudah, beli, yg, ke]
# 5425                                 [byk, campurannya]
#
#                                       Review_Normalized  \
# 10                                     [enak, kuacinya]
# 12    [pengiriman, cepat, pengemasan, bagus, sesuai,...
# 13    [pengemasan, luar, biasa, baik, untuk, rasa, m...
# 15                              [terima kasih, minimal]
# 16         [sudah, beli, untuk, kesekian, kali, mantap]
# ...                                                 ...
# 5421  [seller, sangat, responsif, rasa, belum, dicob...
# 5422                   [imut, banget, pengemasan, aman]
# 5423                  [good, produk, dipercaya, seller]
# 5424                            [sudah, beli, yang, ke]
# 5425                              [banyak, campurannya]
#
#                                          df_token_stemm  \
# 10                                        [enak, kuaci]
# 12    [kirim, cepat, emas, bagus, sesuai, pesan, bel...
# 13    [emas, luar, biasa, baik, untuk, rasa, turut, ...
# 15                              [terima kasih, minimal]
# 16           [sudah, beli, untuk, sekian, kali, mantap]
# ...                                                 ...
# 5421  [seller, sangat, responsif, rasa, belum, coba,...
# 5422                         [imut, banget, emas, aman]
# 5423                    [good, produk, percaya, seller]
# 5424                            [sudah, beli, yang, ke]
# 5425                                   [banyak, campur]
#
#                                            Review_clean
# 10                                           enak kuaci
# 12    kirim cepat emas bagus sesuai pesan coba terim...
# 13    emas dominan asli asli kuaci varian dominan as...
# 15                                 terima kasih minimal
# 16                              beli sekian kali mantap
# ...                                                 ...
# 5421                         seller responsif coba buka
# 5422                              imut banget emas aman
# 5423                         good produk percaya seller
# 5424                                               beli
# 5425                                             campur
#
# [4060 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# Review               0
# Rating               0
# tokenization         0
# Review_Normalized    0
# df_token_stemm       0
# Review_clean         0
# dtype: int64

# %% [markdown]
# # Merge data label

# %%
df_label = pd.read_csv('/content/data_review_label.csv')

# %%
df_label
# Out:
#          Label
# 0     Positive
# 1     Positive
# 2     Negative
# 3     Positive
# 4     Positive
# ...        ...
# 4055  Positive
# 4056  Positive
# 4057  Positive
# 4058  Positive
# 4059  Negative
#
# [4060 rows x 1 columns]

# %%
df_label.isnull().sum()
# Out:
# Label    1
# dtype: int64

# %%
df_label['Label'].fillna(method ='ffill', inplace = True)

# %%
df_label.isnull().sum()
# Out:
# Label    0
# dtype: int64

# %%
df_label['Label'].unique()
# Out:
# array(['Positive', 'Negative', ' Negative', ' Positive', ' Negative '],
#       dtype=object)

# %%
#remove all whitespace in colomn labelling
def remove_whitespace_multiple(text):
    return text.replace(" ", "")

df_label['Label'] = df_label['Label'].apply(remove_whitespace_multiple)

# %%
df_label['Label'].unique()
# Out:
# array(['Positive', 'Negative'], dtype=object)

# %%
#conver data to lowercase
df_label['Label'] = df_label['Label'].str.lower()
df_label
# Out:
#          Label
# 0     positive
# 1     positive
# 2     negative
# 3     positive
# 4     positive
# ...        ...
# 4055  positive
# 4056  positive
# 4057  positive
# 4058  positive
# 4059  negative
#
# [4060 rows x 1 columns]

# %% [markdown]
# # Merge Labells to Dataset

# %%
df_review_labelled = pd.concat([df,df_label], axis=1)

# %%
df_review_labelled
# Out:
#                                                  Review  Rating  \
# 0                                                   NaN     NaN
# 1                                                   NaN     NaN
# 2                                                   NaN     NaN
# 3                                                   NaN     NaN
# 4                                                   NaN     NaN
# ...                                                 ...     ...
# 5421  seller sangat responsif rasa belum dicoba kare...     5.0
# 5422                           imut banget packing aman     5.0
# 5423                        good product trusted seller     5.0
# 5424                                  sudah beli yg ke      5.0
# 5425                                    byk campurannya     4.0
#
#                                            tokenization  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5421  [seller, sangat, responsif, rasa, belum, dicob...
# 5422                      [imut, banget, packing, aman]
# 5423                   [good, product, trusted, seller]
# 5424                              [sudah, beli, yg, ke]
# 5425                                 [byk, campurannya]
#
#                                       Review_Normalized  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5421  [seller, sangat, responsif, rasa, belum, dicob...
# 5422                   [imut, banget, pengemasan, aman]
# 5423                  [good, produk, dipercaya, seller]
# 5424                            [sudah, beli, yang, ke]
# 5425                              [banyak, campurannya]
#
#                                          df_token_stemm  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5421  [seller, sangat, responsif, rasa, belum, coba,...
# 5422                         [imut, banget, emas, aman]
# 5423                    [good, produk, percaya, seller]
# 5424                            [sudah, beli, yang, ke]
# 5425                                   [banyak, campur]
#
#                     Review_clean     Label
# 0                            NaN  positive
# 1                            NaN  positive
# 2                            NaN  negative
# 3                            NaN  positive
# 4                            NaN  positive
# ...                          ...       ...
# 5421  seller responsif coba buka       NaN
# 5422       imut banget emas aman       NaN
# 5423  good produk percaya seller       NaN
# 5424                        beli       NaN
# 5425                      campur       NaN
#
# [5095 rows x 7 columns]

# %%
#df.to_csv('dataset_review_tokped_final_cleaned.csv', index=False)
